# %%
import mysql.connector

#Connect to server
cnx = mysql.connector.connect(
    host = "127.0.0.1",
    port = 3306,
    user = "root",
    password = "@Elav1211")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
query = "SELECT * FROM banking_db.clients"

# %%
df = pd.read_sql(query, cnx)
# Out:
# C:\Users\elava\AppData\Local\Temp\ipykernel_7488\1600954950.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, cnx)

# %%
cnx.close()

# %%
df.head()
# Out:
#   client_id            name  age  location_id joined_bank banking_contact  \
# 0  IND12601   Justin Bishop   58         4796  13-04-2011    Bruce Butler
# 1  IND12649   Timothy Kelly   77        20112  05-11-2016   Stephen Payne
# 2  IND12660    Gregory Reed   61        22456  26-12-2009  James Castillo
# 3  IND12702    Shawn Austin   65         3720  03-03-2020   Anthony Berry
# 4  IND12704  Laura Lawrence   78        26956  23-08-2020      Shawn Long
#
#   nationality                occupation fee_structure loyalty_classification  \
# 0       Asian  Software Test Engineer I          High               Platinum
# 1    European  Account Representative I          High                   Gold
# 2    European       Software Engineer I          High                   Jade
# 3    European                   Actuary           Low                   Jade
# 4    European       Account Coordinator           Mid               Platinum
#
#    ...  bank_deposits  checking_accounts  saving_accounts  \
# 0  ...     1056468.66          215605.85        251540.16
# 1  ...      287081.20          315226.42        123838.95
# 2  ...     1112801.54          381237.56        324567.12
# 3  ...      348082.73          224671.58         45883.63
# 4  ...      319216.36          235784.81         63480.53
#
#    foreign_currency_account  business_lending  properties_owned  \
# 0                  74636.38        3207843.85                 1
# 1                   8521.30         643405.39                 3
# 2                  49397.03        2296981.56                 1
# 3                   7191.36        1239307.34                 3
# 4                   7853.71         865551.18                 3
#
#    risk_weighting  brid  gender_id  iaid
# 0               4     4          2    14
# 1               3     3          2    12
# 2               4     1          1    16
# 3               2     1          2    12
# 4               2     2          1     8
#
# [5 rows x 25 columns]

# %%
df.shape
# Out:
# (2940, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2940 entries, 0 to 2939
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   client_id                 2940 non-null   object
#  1   name                      2940 non-null   object
#  2   age                       2940 non-null   int64
#  3   location_id               2940 non-null   int64
#  4   joined_bank               2940 non-null   object
#  5   banking_contact           2940 non-null   object
#  6   nationality               2940 non-null   object
#  7   occupation                2940 non-null   object
#  8   fee_structure             2940 non-null   object
#  9   loyalty_classification    2940 non-null   object
#  10  estimated_income          2940 non-null   float64
#  11  superannuation_savings    2940 non-null   float64
#  12  amount_of_credit_cards    2940 non-null   int64
#  13  credit_card_balance       2940 non-null   float64
#  14  bank_loans                2940 non-null   float64
#  15  bank_deposits             2940 non-null   float64
#  16  checking_accounts         2940 non-null   float64
#  17  saving_accounts           2940 non-null   float64
#  18  foreign_currency_account  2940 non-null   float64
#  19  business_lending          2940 non-null   float64
#  20  properties_owned          2940 non-null   int64
#  21  risk_weighting            2940 non-null   int64
#  22  brid                      2940 non-null   int64
#  23  gender_id                 2940 non-null   int64
#  24  iaid                      2940 non-null   int64
# dtypes: float64(9), int64(8), object(8)
# memory usage: 574.3+ KB

# %%
#Generate descriptive statistics for the dataframe
df.describe()
# Out:
#                age   location_id  estimated_income  superannuation_savings  \
# count  2940.000000   2940.000000       2940.000000             2940.000000
# mean     51.052721  21556.638776     171474.564701            25537.537588
# std      19.865992  12452.561124     112256.335403            16293.994988
# min      17.000000     12.000000      15919.480000             1482.030000
# 25%      34.000000  10803.500000      82742.115000            12506.737500
# 50%      51.000000  21147.500000     142313.480000            22371.550000
# 75%      69.000000  31985.750000     242817.330000            35476.867500
# max      85.000000  43369.000000     521159.980000            75963.900000
#
#        amount_of_credit_cards  credit_card_balance    bank_loans  \
# count             2940.000000          2940.000000  2.940000e+03
# mean                 1.464286          3174.061119  5.929354e+05
# std                  0.675546          2499.212657  4.586359e+05
# min                  1.000000             1.170000  0.000000e+00
# 25%                  1.000000          1231.735000  2.396281e+05
# 50%                  1.000000          2560.165000  4.821348e+05
# 75%                  2.000000          4522.632500  8.295056e+05
# max                  3.000000         13991.990000  2.667557e+06
#
#        bank_deposits  checking_accounts  saving_accounts  \
# count   2.940000e+03       2.940000e+03     2.940000e+03
# mean    6.696077e+05       3.196736e+05     2.325065e+05
# std     6.458076e+05       2.812101e+05     2.302543e+05
# min     0.000000e+00       0.000000e+00     0.000000e+00
# 25%     2.042351e+05       1.193008e+05     7.444691e+04
# 50%     4.590371e+05       2.417221e+05     1.634431e+05
# 75%     9.414633e+05       4.338220e+05     3.136847e+05
# max     3.890598e+06       1.969923e+06     1.724118e+06
#
#        foreign_currency_account  business_lending  properties_owned  \
# count               2940.000000      2.940000e+03       2940.000000
# mean               29924.059065      8.663040e+05          1.518707
# std                23169.058451      6.401003e+05          1.101821
# min                   45.000000      0.000000e+00          0.000000
# 25%                11927.090000      3.753972e+05          1.000000
# 50%                24316.860000      7.115343e+05          2.000000
# 75%                42027.797500      1.183531e+06          2.000000
# max               124704.870000      3.825962e+06          3.000000
#
#        risk_weighting         brid    gender_id         iaid
# count     2940.000000  2940.000000  2940.000000  2940.000000
# mean         2.249660     2.556463     1.505782    10.420408
# std          1.130894     1.009251     0.500052     5.974096
# min          1.000000     1.000000     1.000000     1.000000
# 25%          1.000000     2.000000     1.000000     5.000000
# 50%          2.000000     3.000000     2.000000    10.500000
# 75%          3.000000     3.000000     2.000000    15.000000
# max          5.000000     4.000000     2.000000    22.000000

# %%
bins = [0, 100000, 300000, float('inf')]
labels = ['Low', 'Med', 'High'] 

df['Income Band'] = pd.cut(df['estimated_income'], bins=bins, labels=labels, right=False)

# %%
df['Income Band'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Income Band'>

# %%
# Examine the distribution of unique cataegories in categorical columns
categorical_cols = df[["brid", "gender_id", "iaid", "amount_of_credit_cards", "nationality", "occupation", "fee_structure", "loyalty_classification", "properties_owned", "risk_weighting", "Income Band"]].columns

for col in categorical_cols:
  print(f"Value Counts for '{col}':")
  display(df[col].value_counts())
# Out:
# Value Counts for 'brid':
# brid
# 3    1318
# 1     650
# 2     488
# 4     484
# Name: count, dtype: int64
# Value Counts for 'gender_id':
# gender_id
# 2    1487
# 1    1453
# Name: count, dtype: int64
# Value Counts for 'iaid':
# iaid
# 8     176
# 13    176
# 15    175
# 11    175
# 4     174
# 12    174
# 1     174
# 2     173
# 14    173
# 3     172
# 9     172
# 10    170
# 7      87
# 18     87
# 5      86
# 22     86
# 19     86
# 6      86
# 20     85
# 17     85
# 16     84
# 21     84
# Name: count, dtype: int64
# Value Counts for 'amount_of_credit_cards':
# amount_of_credit_cards
# 1    1880
# 2     755
# 3     305
# Name: count, dtype: int64
# Value Counts for 'nationality':
# nationality
# European      1283
# Asian          744
# American       494
# Australian     245
# African        174
# Name: count, dtype: int64
# Value Counts for 'occupation':
# occupation
# Associate Professor             26
# Structural Analysis Engineer    26
# Recruiter                       25
# Account Coordinator             24
# Human Resources Manager         24
#                                 ..
# Office Assistant IV              8
# Automation Specialist I          7
# Computer Systems Analyst I       6
# Developer III                    5
# Senior Sales Associate           4
# Name: count, Length: 195, dtype: int64
# Value Counts for 'fee_structure':
# fee_structure
# High    1441
# Mid      944
# Low      555
# Name: count, dtype: int64
# Value Counts for 'loyalty_classification':
# loyalty_classification
# Jade        1304
# Silver       754
# Gold         574
# Platinum     308
# Name: count, dtype: int64
# Value Counts for 'properties_owned':
# properties_owned
# 1    762
# 2    761
# 3    727
# 0    690
# Name: count, dtype: int64
# Value Counts for 'risk_weighting':
# risk_weighting
# 2    1200
# 1     818
# 3     448
# 4     318
# 5     156
# Name: count, dtype: int64
# Value Counts for 'Income Band':
# Income Band
# Med     1477
# Low     1012
# High     451
# Name: count, dtype: int64

# %%
## Univariate Analysis

# %%
for i, predictor in enumerate(df[["brid", "gender_id", "iaid", "amount_of_credit_cards", "nationality", "occupation", "fee_structure", "loyalty_classification", "properties_owned", "risk_weighting", "Income Band"]].columns):
    plt.figure(i)
    sns.countplot(data=df, x=predictor)

# %%
## Bivariate Analysis

# %%
for i, predictor in enumerate(df[["brid", "gender_id", "iaid", "amount_of_credit_cards", "nationality", "occupation", "fee_structure", "loyalty_classification", "properties_owned", "risk_weighting", "Income Band"]].columns):
    plt.figure(i)
    sns.countplot(data=df, x=predictor, hue='nationality')

# %%
# HIstplot of value counts for different Occupation

for col in categorical_cols:
  if col == "Occupation":
    continue
  plt.figure(figsize=(8,4))
  sns.histplot(df[col])
  plt.title('Histogram of Occupation Count')
  plt.xlabel(col)
  plt.ylabel("Count")
  plt.show()

# %%
## Numerical Analysis

# %%
numerical_cols = ['estimated_income', 'superannuation_savings', 'credit_card_balance', 'bank_loans', 'bank_deposits', 'checking_accounts', 'saving_accounts', 'foreign_currency_account', 'business_lending']

# Univariate analysis and visualization
plt.figure(figsize=(15,10))
for i,col in enumerate(numerical_cols):
  plt.subplot(4,3,i+1)
  sns.histplot(df[col],kde=True)
  plt.title(col)
plt.show()

# %%
## Heatmaps

# %%
numerical_cols = ['estimated_income', 'superannuation_savings', 'credit_card_balance', 'bank_loans', 'bank_deposits', 'checking_accounts', 'saving_accounts', 'foreign_currency_account', 'business_lending']

correlation_matrix = df[numerical_cols].corr()

plt.figure(figsize=(12,12))
sns.heatmap(correlation_matrix, annot=True, cmap='crest', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
## Insights of EDA:

## 1. The strongest positive correlation occur among "Bank Deposits" with "Checking Accounts", "Saving Accounts" and "Foreign Currency Account" indicating that customers who maintain high balances in one account type often hold substantial amount/funds across other accounts as well.
